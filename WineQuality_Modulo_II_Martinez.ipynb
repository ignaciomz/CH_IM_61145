# %% [markdown]
# # Modulo II - Machine Learning
#
# Vamos a traer desde Kaggle el dataset de WineQuality

# %%
! pip install -q kaggle
#https://drive.google.com/file/d/15aOxE6V3zKdslsgsxCGQHEEvLHh_5RCo/view?usp=sharing
! gdown --id 15aOxE6V3zKdslsgsxCGQHEEvLHh_5RCo
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=15aOxE6V3zKdslsgsxCGQHEEvLHh_5RCo
# To: /content/kaggle.json
# 100% 63.0/63.0 [00:00<00:00, 187kB/s]

# %%
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
! kaggle datasets list
# Out:
# ref                                                                  title                                           size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------------------------  ---------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# haseebindata/student-performance-predictions                         Student Performance Predictions                  9KB  2024-08-17 06:57:57           5201        114  0.9411765
# uom190346a/sleep-and-health-metrics                                  Sleep and Health Metrics                        73KB  2024-08-31 02:39:09            854         26  1.0
# berkayalan/paris-2024-olympics-medals                                Paris 2024 Olympics Medals                       1KB  2024-08-14 11:02:45           4840         90  1.0
# ...

# %%
# !kaggle datasets download -d yasserh/wine-quality-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/yasserh/wine-quality-dataset
# License(s): CC0-1.0
# ...
#   0% 0.00/21.5k [00:00<?, ?B/s]
# 100% 21.5k/21.5k [00:00<00:00, 26.7MB/s]

# %%
path = '/content/wine-quality-dataset.zip'
path_extract = '/content/wine-quality-dataset/WineQT.csv'

import pandas as pd

df = pd.read_csv(path_extract)
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...
